# %% [markdown]
# # Look up scores for specific variants

# %%
import hail as hl

from gnomad_toolbox.filtering.pext import get_pext_for_variant

# %%
hl.init(backend="local")
# Out:
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.133-4c60fddb171a
# LOGGING: writing to /Users/kchao/code/gnomad-toolbox/gnomad_toolbox/notebooks/hail-20250311-1041-0.2.133-4c60fddb171a.log
# 2025-03-11 10:42:21.888 Hail: WARN: No variant found at chr15:74751897 with alleles ['G', 'A']
# 2025-03-11 10:43:01.980 Hail: WARN: No variant found at chr15:74755085 with alleles ['G', 'A']

# %% [markdown]
# # Get pext score for a single variant

# %% [markdown]
# Example where a variant has a defined pext score.

# %%
var_ht = get_pext_for_variant(contig='chr15', position=74755085, ref='T', alt='C')
var_ht.show(1)
# Out:
# +----------------+-------------------+------------+-------------+
# | locus          | gene_id           | alleles    | gene_symbol |
# +----------------+-------------------+------------+-------------+
# | locus<GRCh38>  | str               | array<str> | str         |
# +----------------+-------------------+------------+-------------+
# | chr15:74755085 | "ENSG00000140505" | ["T","C"]  | "CYP1A2"    |
# +----------------+-------------------+------------+-------------+
#
# +-------------------------+-----+-----------+---------------+
# | most_severe_consequence | lof | lof_flags | exp_prop_mean |
# +-------------------------+-----+-----------+---------------+
# | str                     | str | str       |       float64 |
# +-------------------------+-----+-----------+---------------+
# | "synonymous_variant"    | NA  | NA        |      1.00e+00 |
# +-------------------------+-----+-----------+---------------+
#
# +--------------------------------------------+
# ...

# %% [markdown]
# Example where a variant's pext score is NaN.

# %%
var_ht = get_pext_for_variant(variant='chr22-15528692-C-A')
var_ht.show(1)
# Out:
# +----------------+-------------------+------------+-------------+
# | locus          | gene_id           | alleles    | gene_symbol |
# +----------------+-------------------+------------+-------------+
# | locus<GRCh38>  | str               | array<str> | str         |
# +----------------+-------------------+------------+-------------+
# | chr22:15528692 | "ENSG00000130538" | ["C","A"]  | "OR11H1"    |
# +----------------+-------------------+------------+-------------+
#
# +-------------------------+-----+-----------+---------------+
# | most_severe_consequence | lof | lof_flags | exp_prop_mean |
# +-------------------------+-----+-----------+---------------+
# | str                     | str | str       |       float64 |
# +-------------------------+-----+-----------+---------------+
# | "synonymous_variant"    | NA  | NA        |           NaN |
# +-------------------------+-----+-----------+---------------+
#
# +--------------------------------------------+
# ...
